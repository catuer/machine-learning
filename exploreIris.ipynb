# %% [markdown]
# <a href="https://colab.research.google.com/github/catuer/machine-learning/blob/main/exploreIris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url="https://raw.githubusercontent.com/catuer/machine-learning/main/Iris.csv"
iris=pd.read_csv(url)
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
del iris['Id']
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.index = iris.Species
del iris['Species']
iris.head()
# Out:
#              SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa            5.1           3.5            1.4           0.2
# Iris-setosa            4.9           3.0            1.4           0.2
# Iris-setosa            4.7           3.2            1.3           0.2
# Iris-setosa            4.6           3.1            1.5           0.2
# Iris-setosa            5.0           3.6            1.4           0.2

# %%
iris.mean()
# Out:
# SepalLengthCm    5.843333
# SepalWidthCm     3.054000
# PetalLengthCm    3.758667
# PetalWidthCm     1.198667
# dtype: float64

# %%
iris.mean(axis=1)
# Out:
# Species
# Iris-setosa       2.550
# Iris-setosa       2.375
# Iris-setosa       2.350
# Iris-setosa       2.350
# Iris-setosa       2.550
#                   ...
# Iris-virginica    4.300
# Iris-virginica    3.925
# Iris-virginica    4.175
# Iris-virginica    4.325
# Iris-virginica    3.950
# Length: 150, dtype: float64

# %%
iris.mode()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.0           3.0            1.5           0.2

# %%
iris.quantile(0.25)
# Out:
# SepalLengthCm    5.1
# SepalWidthCm     2.8
# PetalLengthCm    1.6
# PetalWidthCm     0.3
# Name: 0.25, dtype: float64

# %%
iris["SepalLengthCm"].quantile(0.75)
# Out:
# 6.4

# %%
iris["PetalLengthCm"].var()
# Out:
# 3.113179418344519

# %%
iris["PetalLengthCm"].std()
# Out:
# 1.7644204199522626
